# %%
import pandas as pd
import numpy as np
import scipy.stats as st
import seaborn as sns
import sys
import os
import gseapy as gp
import matplotlib.pyplot as plt
import swan_vis as swan
import yaml
from snakemake.io import expand

p = os.path.dirname(os.path.dirname(os.getcwd()))
sys.path.append(p)

from scripts.utils import *
from scripts.mane_utils import *
from scripts.plotting import *

# %%
config_file = '../snakemake/config.yml'
with open(config_file) as f:
    config = yaml.safe_load(f)

# %%
swan_file = '../'+expand(config['data']['sg'], species='human')[0]

# %%
sg = swan.read(swan_file)
# Out:
# Read in graph from ../data/human/swan_graph.p

# %%
sg.edge_adata
# Out:
# AnnData object with n_obs × n_vars = 138 × 606402
#     obs: 'dataset', 'total_counts'
#     var: 'edge_id'
#     layers: 'counts', 'tpm'

# %%
genes = ['BIN1', 'MAPT', 'PKM', 'TPM1']

# %%
# get edges associated with transcripts from given input genes
# limit to just exons
t_df = sg.t_df.loc[sg.t_df.gname.isin(genes)]
e_df = swan.pivot_path_list(t_df, 'path')
e_df = e_df.loc[e_df.edge_id.isin(sg.edge_df.loc[sg.edge_df.edge_type=='exon'].index.tolist())]
eids = e_df.edge_id.unique().tolist()
e_df = e_df.merge(sg.t_df[['gname', 'gid']],
                  how='left', 
                  left_index=True, 
                  right_index=True)
e_df.head()
# Out:
#                        edge_id gname              gid
# tid
# ENSG00000067225[1,1,1]  298641   PKM  ENSG00000067225
# ENSG00000067225[1,1,1]  298622   PKM  ENSG00000067225
# ENSG00000067225[1,1,1]  298624   PKM  ENSG00000067225
# ENSG00000067225[1,1,1]  298626   PKM  ENSG00000067225
# ENSG00000067225[1,1,1]  298628   PKM  ENSG00000067225

# %%
# df of tid <-> edge id mapping to find exons 
# that are compatible with one another
fname = 'pilot_tid_eid_map.tsv'
e_df.to_csv(fname, sep='\t')

# %%
type(eids[0])
sg.edge_adata.var.dtypes
print(len(sg.edge_adata.var.index))
print(len(sg.edge_df.index))
# Out:
# 606402
# 1023930

# %%
# subset edge adata by the input genes
edge_adata = sg.edge_adata.copy()
# print(len(eids))
eids = sg.edge_adata.var.loc[sg.edge_adata.var.edge_id.isin(eids)].index.tolist()
# print(len(edge_var.index))
edge_adata = edge_adata[:, eids]

# %%
df = swan.calc_tpm(edge_adata)

# %%
# tpm of each exon in each library
fname = 'pilot_exon_tpm.tsv'
df.to_csv(fname, sep='\t')

# %%
for g in genes:
    sg.gen_report(g,
                  f'figures/',
                  novelty=True,
                  cmap='viridis',
                  indicate_novel=True,
                  transcript_col='tname',
                  include_unexpressed=True,
                  datasets={'dataset': ['h9_neural_crest_1_1']})
    sg.gen_report(g,
                  f'figures/',
                  novelty=True,
                  cmap='magma',
                  transcript_col='tname',
                  display_numbers=True,
                  browser=True,
                  layer='pi',
                  include_unexpressed=True,
                  datasets={'dataset': ['h9_neural_crest_1_1']})
# Out:
# /Users/fairliereese/miniconda3/envs/base_clone/lib/python3.7/site-packages/swan_vis/swangraph.py:1333: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   t_df['sum'] = np.log2(t_df+1).sum(axis=1)
# Plotting transcripts for ENSG00000136717
# Saving transcript path graph for ENSG00000136717[1,4,1] as figures/_novel_ENSG00000136717[1,4,1]_path.png
# Saving transcript path graph for ENSG00000136717[1,2,1] as figures/_novel_ENSG00000136717[1,2,1]_path.png
# Saving transcript path graph for ENSG00000136717[1
1]_path.png
# Saving transcript path graph for ENSG00000136717[1,6,1] as figures/_browser_ENSG00000136717[1,6,1]_path.png
# Saving transcript path graph for ENSG00000136717[4,15,1] as figures/_browser_ENSG00000136717[4,15,1]_path.png
# Saving transcript path graph for ENSG00000136717[3,12,1] as figures/_browser_ENSG00000136717[3,12,1]_path.png
# Saving transcript path graph for ENSG00000136717[2,5,1] as figures/_browser_ENSG00000136717[2,5,1]_path.png
# Saving transcript path graph for ENSG00000136717[1,9,1] as figures/_browser_ENSG00000136717[1,9,1]_path.png
# Saving transcript path graph for ENSG00000136717[2,6,1] as figures/_browser_ENSG00000136717[2,6,1]_path.png
# Saving transcript path graph for ENSG00000136717[2,7,1] as figures/_browser_ENSG00000136717[2,7,1]_path.png
# Saving transcript path graph for ENSG00000136717[1,7,1] as figures/_browser_ENSG00000136717[1,7,1]_path.png
# Saving transcript path graph for ENSG00000136717[1,21,1] as figures/_browser_ENSG00000136717[1,21,1]_path.png
# Saving transcript path graph for ENSG00000136717[2,21,1] as figures/_browser_ENSG00000136717[2,21,1]_path.png
# Saving transcript path graph for ENSG00000136717[2,9,1] as figures/_browser_ENSG00000136717[2,9,1]_path.png
# Saving transcript path graph for ENSG00000136717[2,20,1] as figures/_browser_ENSG00000136717[2,20,1]_path.png
# Saving transcript path graph for ENSG00000136717[2,8,1] as figures/_browser_ENSG00000136717[2,8,1]_path.png
# Saving transcript path graph for ENSG00000136717[2,11,1] as figures/_browser_ENSG00000136717[2,11,1]_path.png
# Saving transcript path graph for ENSG00000136717[1,11,1] as figures/_browser_ENSG00000136717[1,11,1]_path.png
# Saving transcript path graph for ENSG00000136717[1,10,1] as figures/_browser_ENSG00000136717[1,10,1]_path.png
# Saving transcript path graph for ENSG00000136717[2,10,1] as figures/_browser_ENSG00000136717[2,10,1]_path.png
# Generating report for ENSG00000136717
#
# Plotting transcripts for ENSG00000186868
# Saving transcript path graph for ENSG00000186868[1,8,3] as figures/_novel_ENSG00000186868[1,8,3]_path.png
# Saving transcript path graph for ENSG00000186868[1,8,2] as figures/_novel_ENSG00000186868[1,8,2]_path.png
# Saving transcript path graph for ENSG00000186868[1,7,3] as figures/_novel_ENSG00000186868[1,7,3]_path.png
# Saving transcript path graph for ENSG00000186868[1,22,3] as figures/_novel_ENSG00000186868[1,22,3]_path.png
# Saving transcript path graph for ENSG00000186868[6,22,1] as figures/_novel_ENSG00000186868[6,22,1]_path.png
# Saving transcript path graph for ENSG00000186868[1,21,3] as figures/_novel_ENSG00000186868[1,21,3]_path.png
# Saving transcript path graph for ENSG00000186868[4,14,7] as figures/_novel_ENSG00000186868[4,14,7]_path.png
# Saving transcript path graph for ENSG00000186868[1,7,11] as figures/_novel_ENSG00000186868[1,7,11]_path.png
# Saving transcript path graph for ENSG00000186868[6,21,1] as figures/_novel_ENSG00000186868[6,21,1]_path.png
# Saving transcript path graph for ENSG00000186868[1,22,11] as figures/_novel_ENSG00000186868[1,22,11]_path.png
# Saving transcript path graph for ENSG00000186868[1,8,11] as figures/_novel_ENSG00000186868[1,8,11]_path.png
# Saving transcript path graph for ENSG00000186868[1,7,1] as figures/_novel_ENSG00000186868[1,7,1]_path.png
# Saving transcript path graph for ENSG00000186868[2,13,2] as figures/_novel_ENSG00000186868[2,13,2]_path.png
# Saving transcript path graph for ENSG00000186868[2,11,2] as figures/_novel_ENSG00000186868[2,11,2]_path.png
# Saving transcript path graph for ENSG00000186868[6,3,1] as figures/_novel_ENSG00000186868[6,3,1]_path.png
# Saving transcript path graph for ENSG00000186868[1,3,3] as figures/_novel_ENSG00000186868[1,3,3]_path.png
# Saving transcript path graph for ENSG00000186868[3,17,3] as figures/_novel_ENSG00000186868[3,17,3]_path.png
# Saving transcript path graph for ENSG00000186868[2,12,2] as figures/_novel_ENSG00000186868[2,12,2]_path.png
# Saving transcript path graph for ENSG00000186868[7,14,10] as figures/_novel_ENSG00000186868[7,14,10]_path.png
# Generating report for ENSG00000186868
# /Users/fairliereese/miniconda3/envs/base_clone/lib/python3.7/site-packages/swan_vis/report.py:259: RuntimeWarning: invalid value encountered in double_scalars
#   norm_val = (entry[col]-self.g_min)/(self.g_max-self.g_min)
# Plotting transcripts for ENSG00000186868
# Saving transcript path graph for ENSG00000186868[1,8,3] as figures/_browser_ENSG00000186868[1,8,3]_path.png
# Saving transcript path graph for ENSG00000186868[1,8,2] as figures/_browser_ENSG00000186868[1,8,2]_path.png
# Saving transcript path graph for ENSG00000186868[1,7,3] as figures/_browser_ENSG00000186868[1,7,3]_path.png
# Saving transcript path graph for ENSG00000186868[1,22,3] as figures/_browser_ENSG00000186868[1,22,3]_path.png
# Saving transcript path graph for ENSG00000186868[6,22,1] as figures/_browser_ENSG00000186868[6,22,1]_path.png
# Saving transcript path graph for ENSG00000186868[1,21,3] as figures/_browser_ENSG00000186868[1,21,3]_path.png
# Saving transcript path graph for ENSG00000186868[4,14,7] as figures/_browser_ENSG00000186868[4,14,7]_path.png
# Saving transcript path graph for ENSG00000186868[1,7,11] as figures/_browser_ENSG00000186868[1,7,11]_path.png
# Saving transcript path graph for ENSG00000186868[6,21,1] as figures/_browser_ENSG00000186868[6,21,1]_path.png
# Saving transcript path graph for ENSG00000186868[1,22,11] as figures/_browser_ENSG00000186868[1,22,11]_path.png
# Saving transcript path graph for ENSG00000186868[1,8,11] as figures/_browser_ENSG00000186868[1,8,11]_path.png
# Saving transcript path graph for ENSG00000186868[1,7,1] as figures/_browser_ENSG00000186868[1,7,1]_path.png
# Saving transcript path graph for ENSG00000186868[2,13,2] as figures/_browser_ENSG00000186868[2,13,2]_path.png
# Saving transcript path graph for ENSG00000186868[2,11,2] as figures/_browser_ENSG00000186868[2,11,2]_path.png
# Saving transcript path graph for ENSG00000186868[6,3,1] as figures/_browser_ENSG00000186868[6,3,1]_path.png
# Saving transcript path graph for ENSG00000186868[1,3,3] as figures/_browser_ENSG00000186868[1,3,3]_path.png
# Saving transcript path graph for ENSG00000186868[3,17,3] as figures/_browser_ENSG00000186868[3,17,3]_path.png
# Saving transcript path graph for ENSG00000186868[2,12,2] as figures/_browser_ENSG00000186868[2,12,2]_path.png
# Saving transcript path graph for ENSG00000186868[7,14,10] as figures/_browser_ENSG00000186868[7,14,10]_path.png
# Generating report for ENSG00000186868
#
# Plotting transcripts for ENSG00000067225
# Saving transcript path graph for ENSG00000067225[1,1,1] as figures/_novel_ENSG00000067225[1,1,1]_path.png
# Saving transcript path graph for ENSG00000067225[1,46,1] as figures/_novel_ENSG00000067225[1,46,1]_path.png
# Saving transcript path graph for ENSG00000067225[1,40,1] as figures/_novel_ENSG00000067225[1,40,1]_path.png
# Saving transcript path graph for ENSG00000067225[4,7,1] as figures/_novel_ENSG00000067225[4,7,1]_path.png
# Saving transcript path graph for ENSG00000067225[5,8,1] as figures/_novel_ENSG00000067225[5,8,1]_path.png
# Saving transcript path graph for ENSG00000067225[3,50,1] as figures/_novel_ENSG00000067225[3,50,1]_path.png
# Saving transcript path graph for ENSG00000067225[1,26,1] as figures/_novel_ENSG00000067225[1,26,1]_path.png
# Saving transcript path graph for ENSG00000067225[1,37,1] as figures/_novel_ENSG00000067225[1,37,1]_path.png
# Saving transcript path graph for ENSG00000067225[1,27,1] as figures/_novel_ENSG00000067225[1,27,1]_path.png
# Saving transcript path graph for ENSG00000067225[1,41,1] as figures/_novel_ENSG00000067225[1,41,1]_path.png
# Saving transcript path graph for ENSG00000067225[1,42,1] as figures/_novel_ENSG00000067225[1,42,1]_path.png
# Saving transcript path graph for ENSG00000067225[1,29,1] as figures/_novel_ENSG00000067225[1,29,1]_path.png
# Saving transcript path graph for ENSG00000067225[1,44,1] as figures/_novel_ENSG00000067225[1,44,1]_path.png
# Saving transcript path graph for ENSG00000067225[1,33,1] as figures/_novel_ENSG00000067225[1,33,1]_path.png
# Saving transcript path graph for ENSG00000067225[3,51,1] as figures/_novel_ENSG00000067225[3,51,1]_path.png
# Saving transcript path graph for ENSG00000067225[1,49,1] as figures/_novel_ENSG00000067225[1,49,1]_path.png
# Saving transcript path graph for ENSG00000067225[1,28,1] as figures/_novel_ENSG00000067225[1,28,1]_path.png
# Saving transcript path graph for ENSG00000067225[1,35,1] as figures/_novel_ENSG00000067225[1,35,1]_path.png
# Saving transcript path graph for ENSG00000067225[1,4,1] as figures/_novel_ENSG00000067225[1,4,1]_path.png
# Saving transcript path graph for ENSG00000067225[1,31,1] as figures/_novel_ENSG00000067225[1,31,1]_path.png
# Saving transcript path graph for ENSG00000067225[3,1,1] as figures/_novel_ENSG00000067225[3,1,1]_path.png
# Saving transcript path graph for ENSG00000067225[1,48,1] as figures/_novel_ENSG00000067225[1,48,1]_path.png
# Saving transcript path graph for ENSG00000067225[1,38,1] as figures/_novel_ENSG00000067225[1,38,1]_path.png
# Saving transcript path graph for ENSG00000067225[14,50,1] as figures/_novel_ENSG00000067225[14,50,1]_path.png
# Saving transcript path graph for ENSG00000067225[1,36,1] as figures/_novel_ENSG00000067225[1,36,1]_path.png
# Saving transcript path graph for ENSG00000067225[1,43,1] as figures/_novel_ENSG00000067225[1,43,1]_path.png
# Saving transcript path graph for ENSG00000067225[1,32,1] as figures/_novel_ENSG00000067225[1,32,1]_path.png
# Saving transcript path graph for ENSG00000067225[1,47,1] as figures/_novel_ENSG00000067225[1,47,1]_path.png
# Saving transcript path graph for ENSG00000067225[1,45,1] as figures/_novel_ENSG00000067225[1,45,1]_path.png
# Saving transcript path graph for ENSG00000067225[1,39,1] as figures/_novel_ENSG00000067225[1,39,1]_path.png
# Saving transcript path graph for ENSG00000067225[14,52,1] as figures/_novel_ENSG00000067225[14,52,1]_path.png
# Saving transcript path graph for ENSG00000067225[7,11,7] as figures/_novel_ENSG00000067225[7,11,7]_path.png
# Saving transcript path graph for ENSG00000067225[3,46,1] as figures/_novel_ENSG00000067225[3,46,1]_path.png
# Saving transcript path graph for ENSG00000067225[1,34,1] as figures/_novel_ENSG00000067225[1,34,1]_path.png
# Saving transcript path graph for ENSG00000067225[14,53,1] as figures/_novel_ENSG00000067225[14,53,1]_path.png
# Saving transcript path graph for ENSG00000067225[1,30,1] as figures/_novel_ENSG00000067225[1,30,1]_path.png
# Saving transcript path graph for ENSG00000067225[8,12,8] as figures/_novel_ENSG00000067225[8,12,8]_path.png
# Saving transcript path graph for ENSG00000067225[3,3,1] as figures/_novel_ENSG00000067225[3,3,1]_path.png
# Saving transcript path graph for ENSG00000067225[12,25,1] as figures/_novel_ENSG00000067225[12,25,1]_path.png
# Saving transcript path graph for ENSG00000067225[1,3,1] as figures/_novel_ENSG00000067225[1,3,1]_path.png
# Saving transcript path graph for ENSG00000067225[1,5,2] as figures/_novel_ENSG00000067225[1,5,2]_path.png
# Saving transcript path graph for ENSG00000067225[9,13,9] as figures/_novel_ENSG00000067225[9,13,9]_path.png
# Saving transcript path graph for ENSG00000067225[1,18,12] as figures/_novel_ENSG00000067225[1,18,12]_path.png
# Saving transcript path graph for ENSG00000067225[1,20,1] as figures/_novel_ENSG00000067225[1,20,1]_path.png
# Saving transcript path graph for ENSG00000067225[2,2,2] as figures/_novel_ENSG00000067225[2,2,2]_path.png
# Saving transcript path graph for ENSG00000067225[1,5,1] as figures/_novel_ENSG00000067225[1,5,1]_path.png
# Saving transcript path graph for ENSG00000067225[14,51,1] as figures/_novel_ENSG00000067225[14,51,1]_path.png
# Saving transcript path graph for ENSG00000067225[14,1,1] as figures/_novel_ENSG00000067225[14,1,1]_path.png
# Saving transcript path graph for ENSG00000067225[6,9,4] as figures/_novel_ENSG00000067225[6,9,4]_path.png
# Generating report for ENSG00000067225
#
# Plotting transcripts for ENSG00000067225
# Saving transcript path graph for ENSG00000067225[1,1,1] as figures/_browser_ENSG00000067225[1,1,1]_path.png
# Saving transcript path graph for ENSG00000067225[1
1]_path.png
# Saving transcript path graph for ENSG00000067225[1,3,1] as figures/_browser_ENSG00000067225[1,3,1]_path.png
# Saving transcript path graph for ENSG00000067225[1,5,2] as figures/_browser_ENSG00000067225[1,5,2]_path.png
# Saving transcript path graph for ENSG00000067225[9,13,9] as figures/_browser_ENSG00000067225[9,13,9]_path.png
# Saving transcript path graph for ENSG00000067225[1,18,12] as figures/_browser_ENSG00000067225[1,18,12]_path.png
# Saving transcript path graph for ENSG00000067225[1,20,1] as figures/_browser_ENSG00000067225[1,20,1]_path.png
# Saving transcript path graph for ENSG00000067225[2,2,2] as figures/_browser_ENSG00000067225[2,2,2]_path.png
# Saving transcript path graph for ENSG00000067225[1,5,1] as figures/_browser_ENSG00000067225[1,5,1]_path.png
# Saving transcript path graph for ENSG00000067225[14,51,1] as figures/_browser_ENSG00000067225[14,51,1]_path.png
# Saving transcript path graph for ENSG00000067225[14,1,1] as figures/_browser_ENSG00000067225[14,1,1]_path.png
# Saving transcript path graph for ENSG00000067225[6,9,4] as figures/_browser_ENSG00000067225[6,9,4]_path.png
# Generating report for ENSG00000067225
#
# Plotting transcripts for ENSG00000140416
# Saving transcript path graph for ENSG00000140416[3,14,8] as figures/_novel_ENSG00000140416[3,14,8]_path.png
# Saving transcript path graph for ENSG00000140416[1,8,9] as figures/_novel_ENSG00000140416[1,8,9]_path.png
# Saving transcript path graph for ENSG00000140416[1,10,9] as figures/_novel_ENSG00000140416[1,10,9]_path.png
# Saving transcript path graph for ENSG00000140416[1,1,1] as figures/_novel_ENSG00000140416[1,1,1]_path.png
# Saving transcript path graph for ENSG00000140416[1,6,9] as figures/_novel_ENSG00000140416[1,6,9]_path.png
# Saving transcript path graph for ENSG00000140416[3,103,9] as figures/_novel_ENSG00000140416[3,103,9]_path.png
# Saving transcript path graph for ENSG00000140416[1,4,9] as figures/_novel_ENSG00000140416[1,4,9]_path.png
# Saving transcript path graph for ENSG00000140416[1,5,1] as figures/_novel_ENSG00000140416[1,5,1]_path.png
# Saving transcript path graph for ENSG00000140416[1,7,2] as figures/_novel_ENSG00000140416[1,7,2]_path.png
# Saving transcript path graph for ENSG00000140416[1,71,1] as figures/_novel_ENSG00000140416[1,71,1]_path.png
# Saving transcript path graph for ENSG00000140416[1,60,1] as figures/_novel_ENSG00000140416[1,60,1]_path.png
# Saving transcript path graph for ENSG00000140416[1,81,1] as figures/_novel_ENSG00000140416[1,81,1]_path.png
# Saving transcript path graph for ENSG00000140416[3,98,17] as figures/_novel_ENSG00000140416[3,98,17]_path.png
# Saving transcript path graph for ENSG00000140416[12,38,1] as figures/_novel_ENSG00000140416[12,38,1]_path.png
# Saving transcript path graph for ENSG00000140416[1,61,1] as figures/_novel_ENSG00000140416[1,61,1]_path.png
# Saving transcript path graph for ENSG00000140416[1,80,9] as figures/_novel_ENSG00000140416[1,80,9]_path.png
# Saving transcript path graph for ENSG00000140416[3,16,1] as figures/_novel_ENSG00000140416[3,16,1]_path.png
# Saving transcript path graph for ENSG00000140416[1,57,9] as figures/_novel_ENSG00000140416[1,57,9]_path.png
# Saving transcript path graph for ENSG00000140416[3,99,1] as figures/_novel_ENSG00000140416[3,99,1]_path.png
# Saving transcript path graph for ENSG00000140416[1,10,8] as figures/_novel_ENSG00000140416[1,10,8]_path.png
# Saving transcript path graph for ENSG00000140416[3,101,1] as figures/_novel_ENSG00000140416[3,101,1]_path.png
# Saving transcript path graph for ENSG00000140416[1,62,9] as figures/_novel_ENSG00000140416[1,62,9]_path.png
# Saving transcript path graph for ENSG00000140416[1,45,1] as figures/_novel_ENSG00000140416[1,45,1]_path.png
# Saving transcript path graph for ENSG00000140416[3,26,13] as figures/_novel_ENSG00000140416[3,26,13]_path.png
# Saving transcript path graph for ENSG00000140416[1,9,1] as figures/_novel_ENSG00000140416[1,9,1]_path.png
# Saving transcript path graph for ENSG00000140416[3,17,6] as figures/_novel_ENSG00000140416[3,17,6]_path.png
# Saving transcript path graph for ENSG00000140416[1,95,1] as figures/_novel_ENSG00000140416[1,95,1]_path.png
# Saving transcript path graph for ENSG00000140416[1
1]_path.png
# Saving transcript path graph for ENSG00000140416[1,40,1] as figures/_novel_ENSG00000140416[1,40,1]_path.png
# Saving transcript path graph for ENSG00000140416[3,100,1] as figures/_novel_ENSG00000140416[3,100,1]_path.png
# Saving transcript path graph for ENSG00000140416[9,31,12] as figures/_novel_ENSG00000140416[9,31,12]_path.png
# Saving transcript path graph for ENSG00000140416[1,94,9] as figures/_novel_ENSG00000140416[1,94,9]_path.png
# Saving transcript path graph for ENSG00000140416[1,84,1] as figures/_novel_ENSG00000140416[1,84,1]_path.png
# Saving transcript path graph for ENSG00000140416[1,23,9] as figures/_novel_ENSG00000140416[1,23,9]_path.png
# Saving transcript path graph for ENSG00000140416[1,47,9] as figures/_novel_ENSG00000140416[1,47,9]_path.png
# Saving transcript path graph for ENSG00000140416[1,43,9] as figures/_novel_ENSG00000140416[1,43,9]_path.png
# Saving transcript path graph for ENSG00000140416[3,13,5] as figures/_novel_ENSG00000140416[3,13,5]_path.png
# Saving transcript path graph for ENSG00000140416[1,64,1] as figures/_novel_ENSG00000140416[1,64,1]_path.png
# Saving transcript path graph for ENSG00000140416[1,50,1] as figures/_novel_ENSG00000140416[1,50,1]_path.png
# Saving transcript path graph for ENSG00000140416[5,25,9] as figures/_novel_ENSG00000140416[5,25,9]_path.png
# Saving transcript path graph for ENSG00000140416[11,36,1] as figures/_novel_ENSG00000140416[11,36,1]_path.png
# Saving transcript path graph for ENSG00000140416[10,34,15] as figures/_novel_ENSG00000140416[10,34,15]_path.png
# Saving transcript path graph for ENSG00000140416[13,1,1] as figures/_novel_ENSG00000140416[13,1,1]_path.png
# Saving transcript path graph for ENSG00000140416[13,8,9] as figures/_novel_ENSG00000140416[13,8,9]_path.png
# Saving transcript path graph for ENSG00000140416[13,5,1] as figures/_novel_ENSG00000140416[13,5,1]_path.png
# Saving transcript path graph for ENSG00000140416[6,24,16] as figures/_novel_ENSG00000140416[6,24,16]_path.png
# Saving transcript path graph for ENSG00000140416[1,20,14] as figures/_novel_ENSG00000140416[1,20,14]_path.png
# Saving transcript path graph for ENSG00000140416[1,56,9] as figures/_novel_ENSG00000140416[1,56,9]_path.png
# Saving transcript path graph for ENSG00000140416[1,49,8] as figures/_novel_ENSG00000140416[1,49,8]_path.png
# Saving transcript path graph for ENSG00000140416[1,19,10] as figures/_novel_ENSG00000140416[1,19,10]_path.png
# Generating report for ENSG00000140416
#
# Plotting transcripts for ENSG00000140416
# Saving transcript path graph for ENSG00000140416[3,14,8] as figures/_browser_ENSG00000140416[3,14,8]_path.png
# Saving transcript path graph for ENSG00000140416[1,8,9] as figures/_browser_ENSG00000140416[1,8,9]_path.png
# Saving transcript path graph for ENSG00000140416[1,10,9] as figures/_browser_ENSG00000140416[1,10,9]_path.png
# Saving transcript path graph for ENSG00000140416[1,1,1] as figures/_browser_ENSG00000140416[1,1,1]_path.png
# Saving transcript path graph for ENSG00000140416[1,6,9] as figures/_browser_ENSG00000140416[1,6,9]_path.png
# Saving transcript path graph for ENSG00000140416[3,103,9] as figures/_browser_ENSG00000140416[3,103,9]_path.png
# Saving transcript path graph for ENSG00000140416[1,4,9] as figures/_browser_ENSG00000140416[1,4,9]_path.png
# Saving transcript path graph for ENSG00000140416[1,5,1] as figures/_browser_ENSG00000140416[1,5,1]_path.png
# Saving transcript path graph for ENSG00000140416[1,7,2] as figures/_browser_ENSG00000140416[1,7,2]_path.png
# Saving transcript path graph for ENSG00000140416[1,71,1] as figures/_browser_ENSG00000140416[1,71,1]_path.png
# Saving transcript path graph for ENSG00000140416[1,60,1] as figures/_browser_ENSG00000140416[1,60,1]_path.png
# Saving transcript path graph for ENSG00000140416[1,81,1] as figures/_browser_ENSG00000140416[1,81,1]_path.png
# Saving transcript path graph for ENSG00000140416[3,98,17] as figures/_browser_ENSG00000140416[3,98,17]_path.png
# Saving transcript path graph for ENSG00000140416[12,38,1] as figures/_browser_ENSG00000140416[12,38,1]_path.png
# Saving transcript path graph for ENSG00000140416[1,61,1] as figures/_browser_ENSG00000140416[1,61,1]_path.png
# Saving transcript path graph for ENSG00000140416[1
9]_path.png
# Saving transcript path graph for ENSG00000140416[1,97,1] as figures/_browser_ENSG00000140416[1,97,1]_path.png
# Saving transcript path graph for ENSG00000140416[1,86,9] as figures/_browser_ENSG00000140416[1,86,9]_path.png
# Saving transcript path graph for ENSG00000140416[1,70,1] as figures/_browser_ENSG00000140416[1,70,1]_path.png
# Saving transcript path graph for ENSG00000140416[1,96,9] as figures/_browser_ENSG00000140416[1,96,9]_path.png
# Saving transcript path graph for ENSG00000140416[1,67,1] as figures/_browser_ENSG00000140416[1,67,1]_path.png
# Saving transcript path graph for ENSG00000140416[3,12,3] as figures/_browser_ENSG00000140416[3,12,3]_path.png
# Saving transcript path graph for ENSG00000140416[1,72,9] as figures/_browser_ENSG00000140416[1,72,9]_path.png
# Saving transcript path graph for ENSG00000140416[1,68,1] as figures/_browser_ENSG00000140416[1,68,1]_path.png
# Saving transcript path graph for ENSG00000140416[1,85,1] as figures/_browser_ENSG00000140416[1,85,1]_path.png
# Saving transcript path graph for ENSG00000140416[1,79,1] as figures/_browser_ENSG00000140416[1,79,1]_path.png
# Saving transcript path graph for ENSG00000140416[3,15,4] as figures/_browser_ENSG00000140416[3,15,4]_path.png
# Saving transcript path graph for ENSG00000140416[1,44,9] as figures/_browser_ENSG00000140416[1,44,9]_path.png
# Saving transcript path graph for ENSG00000140416[1,83,1] as figures/_browser_ENSG00000140416[1,83,1]_path.png
# Saving transcript path graph for ENSG00000140416[1,76,1] as figures/_browser_ENSG00000140416[1,76,1]_path.png
# Saving transcript path graph for ENSG00000140416[1,40,1] as figures/_browser_ENSG00000140416[1,40,1]_path.png
# Saving transcript path graph for ENSG00000140416[3,100,1] as figures/_browser_ENSG00000140416[3,100,1]_path.png
# Saving transcript path graph for ENSG00000140416[9,31,12] as figures/_browser_ENSG00000140416[9,31,12]_path.png
# Saving transcript path graph for ENSG00000140416[1,94,9] as figures/_browser_ENSG00000140416[1,94,9]_path.png
# Saving transcript path graph for ENSG00000140416[1,84,1] as figures/_browser_ENSG00000140416[1,84,1]_path.png
# Saving transcript path graph for ENSG00000140416[1,23,9] as figures/_browser_ENSG00000140416[1,23,9]_path.png
# Saving transcript path graph for ENSG00000140416[1,47,9] as figures/_browser_ENSG00000140416[1,47,9]_path.png
# Saving transcript path graph for ENSG00000140416[1,43,9] as figures/_browser_ENSG00000140416[1,43,9]_path.png
# Saving transcript path graph for ENSG00000140416[3,13,5] as figures/_browser_ENSG00000140416[3,13,5]_path.png
# Saving transcript path graph for ENSG00000140416[1,64,1] as figures/_browser_ENSG00000140416[1,64,1]_path.png
# Saving transcript path graph for ENSG00000140416[1,50,1] as figures/_browser_ENSG00000140416[1,50,1]_path.png
# Saving transcript path graph for ENSG00000140416[5,25,9] as figures/_browser_ENSG00000140416[5,25,9]_path.png
# Saving transcript path graph for ENSG00000140416[11,36,1] as figures/_browser_ENSG00000140416[11,36,1]_path.png
# Saving transcript path graph for ENSG00000140416[10,34,15] as figures/_browser_ENSG00000140416[10,34,15]_path.png
# Saving transcript path graph for ENSG00000140416[13,1,1] as figures/_browser_ENSG00000140416[13,1,1]_path.png
# Saving transcript path graph for ENSG00000140416[13,8,9] as figures/_browser_ENSG00000140416[13,8,9]_path.png
# Saving transcript path graph for ENSG00000140416[13,5,1] as figures/_browser_ENSG00000140416[13,5,1]_path.png
# Saving transcript path graph for ENSG00000140416[6,24,16] as figures/_browser_ENSG00000140416[6,24,16]_path.png
# Saving transcript path graph for ENSG00000140416[1,20,14] as figures/_browser_ENSG00000140416[1,20,14]_path.png
# Saving transcript path graph for ENSG00000140416[1,56,9] as figures/_browser_ENSG00000140416[1,56,9]_path.png
# Saving transcript path graph for ENSG00000140416[1,49,8] as figures/_browser_ENSG00000140416[1,49,8]_path.png
# Saving transcript path graph for ENSG00000140416[1,19,10] as figures/_browser_ENSG00000140416[1,19,10]_path.png
# Generating report for ENSG00000140416
