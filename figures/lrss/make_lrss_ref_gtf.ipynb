# %%
import pandas as pd
import numpy as np
import scipy.stats as st
import seaborn as sns
import sys
import os
import gseapy as gp
import matplotlib.pyplot as plt
import swan_vis as swan
import yaml
from snakemake.io import expand

p = os.path.dirname(os.path.dirname(os.getcwd()))
sys.path.append(p)

from scripts.utils import *
from scripts.mane_utils import *
from scripts.plotting import *

# %%
config_file = '../snakemake/config.yml'
with open(config_file) as f:
    config = yaml.safe_load(f)

# %%
ab = '../'+expand(config['data']['ab'], species='human')[0]
filt_ab = '../'+expand(config['data']['filt_ab'], species='human')[0]
read_annot = '../'+expand(config['data']['read_annot'], species='human')[0]
t_metadata = '../'+expand(config['ref']['cerberus']['t_info'], species='human')[0]
lib_meta = '../'+expand(config['data']['meta'], species='human')[0]
swan_file = '../'+expand(config['data']['sg'], species='human')[0]
cerberus_h5 = '../'+expand(config['data']['cerb_annot'], species='human')[0]
major_isos = '../'+expand(config['data']['major_isos'], species='human', obs_col='sample')[0]
pp_summary = '../'+expand(config['data']['p_pred']['summary'], species='human')[0]
ref_t_metadata = '../'+expand(config['ref']['t_info'], species='human')[0]
ref_g_metadata = '../'+expand(config['ref']['g_info'], species='human')[0]


sr_ab = '../'+config['sr']['ab']


ver = 'v40_cerberus'
min_tpm = 1
gene_subset = 'protein_coding'
obs_col = 'sample'
go_gene_subset = 'protein_coding'

m_lib_meta = '../'+expand(config['data']['meta'], species='mouse')[0]
m_ab = '../'+expand(config['data']['ab'], species='mouse')[0]
m_filt_ab = '../'+expand(config['data']['filt_ab'], species='mouse')[0]
m_read_annot = '../'+expand(config['data']['read_annot'], species='mouse')[0]
m_t_metadata = '../'+expand(config['ref']['cerberus']['t_info'], species='mouse')[0]
m_swan_file = '../'+expand(config['data']['sg'], species='mouse')[0]
m_cerberus_h5 = '../'+expand(config['data']['cerb_annot'], species='mouse')[0]
m_pi_tpm_table = '../'+expand(config['data']['pi_tpm']['triplet'], species='mouse', obs_col='sample')[0]
m_major_isos = '../'+expand(config['data']['major_isos'], species='mouse', obs_col='sample')[0]
m_pp_summary = '../'+expand(config['data']['p_pred']['summary'], species='mouse')[0]
m_ref_t_metadata = '../'+expand(config['ref']['t_info'], species='mouse')[0]
m_ref_g_metadata = '../'+expand(config['ref']['g_info'], species='mouse')[0]
m_ref_gtf = '../'+expand(config['ref']['cerberus']['gtf'], species='mouse')[0]
m_gtf = '../'+expand(config['data']['cerb_gtf'], species='mouse')[0]

mouse_ver = 'vM25_cerberus'

# %% [markdown]
# I want a GTF that's the union of the reference cerberus-ized GTF and the mouse GTF. First I'll try to do that, then I'll try to limit the novel transcripts in the GTF to those that've passed our filtering.

# %%
def get_union_cerb_gtf(gtf1,
                       gtf2, 
                       h5):
    """
    Merge 2 GTFs. Preferentially keep entries from gtf1 vs. gtf2.
    """
    
    def preproc_gtf(gtf):
        df = pr.read_gtf(gtf,
                         duplicate_attr=True,
                         rename_attr=True).df
        df['gene_id'] = cerberus.get_stable_gid(df, 'gene_id')
        df = df.loc[df.gene_id.str.contains('ENSMUS')]
        tids = df.transcript_id.unique().tolist()    
        return df, tids
    
    gtf1_df, gtf1_tids = preproc_gtf(gtf1)
    gtf2_df, gtf2_tids = preproc_gtf(gtf2)    
    
    # filter gtf2 based on unique transcript ids
    # already in gtf1
    new_ids = list(set(gtf1_tids)-set(gtf2_tids))
    gtf2_df = gtf2_df.loc[gtf2_df.transcript_id.isin(new_ids)]
    
    # filter gtf2 based on genes that are in gtf1
    gtf2_df = gtf2_df.loc[gtf2_df.gene_id.isin(gtf1_df.gene_id.tolist())]
    
    # use cerberus functions to fix GTF entries
    ca = cerberus.read(h5)
    tss = pr.PyRanges(ca.tss.rename({'Name': 'tss_id'}, axis=1))
    tes = pr.PyRanges(ca.tes.rename({'Name': 'tes_id'}, axis=1))
    df = pd.concat([gtf1_df, gtf2_df], axis=0) 
    df = cerberus.sort_gtf(df)
    df = cerberus.update_gtf_ends(df, tss, tes)
    
    return df

# %%
df = get_union_cerb_gtf(m_ref_gtf,
                        m_gtf,
                        m_cerberus_h5)
# Out:
# Found attributes with reserved names: ['source'].
# Renaming attributes with suffix '_attr'

# %%
pr.PyRanges(df).to_gtf('vM25_cerberus_2.gtf')

# %%
ref_df = pr.read_gtf(m_ref_gtf, duplicate_attr=True).df
ref_df['gene_id'] = cerberus.get_stable_gid(ref_df, 'gene_id')

# %%
ref_ids = ref_df.transcript_id.unique().tolist()

# %%
df = pr.read_gtf(m_gtf, duplicate_attr=True, rename_attr=True).df
# Out:
# Found attributes with reserved names: ['source'].
# Renaming attributes with suffix '_attr'

# %%
df = df.loc[df.gene_id.str.contains('ENSMUS')]
df['gene_id'] = cerberus.get_stable_gid(df, 'gene_id')

# %%
# filter the new gtf based on unique transcript ids
new_ids = df.transcript_id.unique().tolist()
print(len(new_ids))
new_ids = list(set(new_ids)-set(ref_ids))
print(len(new_ids))
df = df.loc[df.transcript_id.isin(new_ids)]
# Out:
# 149102
# 85674

# %%
# calculate how many transcripts we have and how many new ones we should get

# %%
ca = cerberus.read(m_cerberus_h5)
tss = pr.PyRanges(ca.tss.rename({'Name': 'tss_id'}, axis=1))
tes = pr.PyRanges(ca.tes.rename({'Name': 'tes_id'}, axis=1))

# %%
new_df = pd.concat([ref_df, df], axis=0)

# %%
new_df = cerberus.sort_gtf(new_df)
new_df = cerberus.update_gtf_ends(new_df, tss, tes)

# %%
new_df.head()
# new_df.gene_id.tail()
# Out:
#   Chromosome  Source     Feature      Start        End Score Strand Frame  \
# 0       chrX     NaN        gene  161082474  161258263     .      +     .
# 1       chrX  HAVANA  transcript  161162699  161258263     .      +     .
# 2       chrX  HAVANA        exon  161162699  161163248     .      +     .
# 3       chrX  HAVANA        exon  161171489  161171535     .      +     .
# 4       chrX  HAVANA        exon  161177246  161177317     .      +     .
#
#               gene_id       gene_type  ... transcript_status source_attr  \
# 0  ENSMUSG00000000037  protein_coding  ...               NaN         NaN
# 1  ENSMUSG00000000037  protein_coding  ...               NaN         NaN
# 2  ENSMUSG00000000037  protein_coding  ...               NaN         NaN
# 3  ENSMUSG00000000037  protein_coding  ...               NaN         NaN
# 4  ENSMUSG00000000037  protein_coding  ...               NaN         NaN
#
#   NNC_transcript ISM-suffix_to_IDs ISM_to_IDs ISM_transcript  \
# 0            NaN               NaN        NaN            NaN
# 1            NaN               NaN        NaN            NaN
# 2            NaN               NaN        NaN            NaN
# 3            NaN               NaN        NaN            NaN
# 4            NaN               NaN        NaN            NaN
#
#   transcript_novelty ISM-suffix_transcript ISM-prefix_transcript  \
# 0                NaN                   NaN                   NaN
# 1                NaN                   NaN                   NaN
# 2                NaN                   NaN                   NaN
# 3                NaN                   NaN                   NaN
# 4                NaN                   NaN                   NaN
#
#   ISM-prefix_to_IDs
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 48 columns]

# %%
ref_df.loc[ref_df.gene_id=='ENCODEMG000055991']
# Out:
# Empty DataFrame
# Columns: [Chromosome, Source, Feature, Start, End, Score, Strand, Frame, gene_id, gene_type, gene_name, ic, ic_id, tss_id, tss, tes_id, tes, transcript_id, transcript_name, tes_last_sa_issue, tss_first_sd_issue, original_transcript_name, transcript_support_level, havana_gene, havana_transcript, mgi_id, transcript_type, level, original_transcript_id, protein_id, ccdsid, tag, ont]
# Index: []
#
# [0 rows x 33 columns]

# %%
new_df.Feature.unique()
# Out:
# ['gene', 'transcript', 'exon']
# Categories (3, object): ['exon', 'gene', 'transcript']

# %%
# remove things that don't have a gene in v40
t_df = new_df[['transcript_id', 'gene_id']].drop_duplicates()
t_gids = t_df.gene_id.unique().tolist()
g_df = new_df.loc[new_df.Feature=='gene']
g_gids = g_df.gene_id.unique().tolist()
t_df.loc[~t_df.gene_id.isin(g_gids)]

len(new_df.loc[new_df.gene_id.isin(g_gids)])
new_df = new_df.loc[new_df.gene_id.isin(g_gids)]

# %%
new_df.loc[new_df.gene_id =='ENSMUSG00000097131']
# Out:
# Empty DataFrame
# Columns: [Chromosome, Source, Feature, Start, End, Score, Strand, Frame, gene_id, gene_type, gene_name, ic, ic_id, tss_id, tss, tes_id, tes, transcript_id, transcript_name, tes_last_sa_issue, tss_first_sd_issue, original_transcript_name, transcript_support_level, havana_gene, havana_transcript, mgi_id, transcript_type, level, original_transcript_id, protein_id, ccdsid, tag, ont, gene_status, talon_gene, talon_transcript, source_cerberus, NIC_transcript, transcript_status, source_attr, NNC_transcript, ISM-suffix_to_IDs, ISM_to_IDs, ISM_transcript, transcript_novelty, ISM-suffix_transcript, ISM-prefix_transcript, ISM-prefix_to_IDs]
# Index: []
#
# [0 rows x 48 columns]

# %%
pr.PyRanges(new_df).to_gtf('vM25_cerberus.gtf')

# %%
# new_df.gene_id.head()
# new_df.gene_id.tail()
# new_df.loc[new_df.gene_id.str.contains('.')]
new_df.loc[new_df.gene_id=='ENSMUSG00000097131']
# Out:
#        Chromosome   Source     Feature     Start       End Score Strand Frame  \
# 973796       chr1  ENSEMBL  transcript  72236414  72266186     .      +     .
# 973797       chr1  ENSEMBL        exon  72236414  72236528     .      +     .
# 973798       chr1  ENSEMBL        exon  72237865  72237923     .      +     .
# 973799       chr1  ENSEMBL        exon  72241370  72241503     .      +     .
# 973800       chr1  ENSEMBL        exon  72264742  72266186     .      +     .
# 973801       chr1  ENSEMBL  transcript  72243970  72274919     .      +     .
# 973802       chr1  ENSEMBL        exon  72243970  72244163     .      +     .
# 973803       chr1  ENSEMBL        exon  72264742  72264892     .      +     .
# 973804       chr1  ENSEMBL        exon  72269467  72269548     .      +     .
# 973805       chr1  ENSEMBL        exon  72272147  72274919     .      +     .
# 973806       chr1    TALON  transcript  72254764  72266780     .      +     .
# 973807       chr1    TALON        exon  72254764  72254994     .      +     .
# 973808       chr1    TALON        exon  72261106  72261186     .      +     .
# 973809       chr1    TALON        exon  72262172  72262330     .      +     .
# 973810       chr1    TALON        exon  72264742  72266780     .      +     .
#
#                    gene_id gene_type  ... transcript_status source_attr  \
# 973796  ENSMUSG00000097131   lincRNA  ...             KNOWN     ENSEMBL
# 973797  ENSMUSG00000097131   lincRNA  ...             KNOWN     ENSEMBL
# 973798  ENSMUSG00000097131   lincRNA  ...             KNOWN     ENSEMBL
# 973799  ENSMUSG00000097131   lincRNA  ...             KNOWN     ENSEMBL
# 973800  ENSMUSG00000097131   lincRNA  ...             KNOWN     ENSEMBL
# 973801  ENSMUSG00000097131   lincRNA  ...             KNOWN     ENSEMBL
# 973802  ENSMUSG00000097131   lincRNA  ...             KNOWN     ENSEMBL
# 973803  ENSMUSG00000097131   lincRNA  ...             KNOWN     ENSEMBL
# 973804  ENSMUSG00000097131   lincRNA  ...             KNOWN     ENSEMBL
# 973805  ENSMUSG00000097131   lincRNA  ...             KNOWN     ENSEMBL
# 973806  ENSMUSG00000097131   lincRNA  ...             NOVEL         NaN
# 973807  ENSMUSG00000097131   lincRNA  ...             NOVEL         NaN
# 973808  ENSMUSG00000097131   lincRNA  ...             NOVEL         NaN
# 973809  ENSMUSG00000097131   lincRNA  ...             NOVEL         NaN
# 973810  ENSMUSG00000097131   lincRNA  ...             NOVEL         NaN
#
#        NNC_transcript ISM-suffix_to_IDs ISM_to_IDs ISM_transcript  \
# 973796            NaN               NaN        NaN            NaN
# 973797            NaN               NaN        NaN            NaN
# 973798            NaN               NaN        NaN            NaN
# 973799            NaN               NaN        NaN            NaN
# 973800            NaN               NaN        NaN            NaN
# 973801            NaN               NaN        NaN            NaN
# 973802            NaN               NaN        NaN            NaN
# 973803            NaN               NaN        NaN            NaN
# 973804            NaN               NaN        NaN            NaN
# 973805            NaN               NaN        NaN            NaN
# 973806            NaN               NaN        NaN            NaN
# 973807            NaN               NaN        NaN            NaN
# 973808            NaN               NaN        NaN            NaN
# 973809            NaN               NaN        NaN            NaN
# 973810            NaN               NaN        NaN            NaN
#
#        transcript_novelty ISM-suffix_transcript ISM-prefix_transcript  \
# 973796                NaN                   NaN                   NaN
# 973797                NaN                   NaN                   NaN
# 973798                NaN                   NaN                   NaN
# 973799                NaN                   NaN                   NaN
# 973800                NaN                   NaN                   NaN
# 973801                NaN                   NaN                   NaN
# 973802                NaN                   NaN                   NaN
# 973803                NaN                   NaN                   NaN
# 973804                NaN                   NaN                   NaN
# 973805                NaN                   NaN                   NaN
# 973806                NaN                   NaN                   NaN
# 973807                NaN                   NaN                   NaN
# 973808                NaN                   NaN                   NaN
# 973809                NaN                   NaN                   NaN
# 973810                NaN                   NaN                   NaN
#
#        ISM-prefix_to_IDs
# 973796               NaN
# 973797               NaN
# 973798               NaN
# 973799               NaN
# 973800               NaN
# 973801               NaN
# 973802               NaN
# 973803               NaN
# 973804               NaN
# 973805               NaN
# 973806               NaN
# 973807               NaN
# 973808               NaN
# 973809               NaN
# 973810               NaN
#
# [15 rows x 48 columns]

# %%
# try to make this into a talon db

# %%
# talon_initialize_database \
#     --f vM25_cerberus.gtf \
#     --g mm10 \
#     --a vM25+cerberus \
#     --o vM25_cerberus
