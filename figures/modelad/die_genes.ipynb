# %%
import pandas as pd
import numpy as np
import scipy.stats as st
import seaborn as sns
import sys
import os
import gseapy as gp

# %%
dpi_thresh = 15
p_val_thresh = 0.01

# %%
fname = 'iso_die_results.tsv'
df = pd.read_csv(fname, sep='\t')

# %%
df = df.loc[(df.dpi>=dpi_thresh)&\
        (df.adj_p_val<=p_val_thresh)]

# %%
df.head()
# Out:
#     Unnamed: 0                 gid         p_val        dpi  \
# 4            4  ENSMUSG00000002459  4.076072e-08  16.866475
# 18          18  ENSMUSG00000048960  6.514161e-04  21.000706
# 38          38  ENSMUSG00000025933  1.515946e-42  27.394122
# 39          39  ENSMUSG00000025934  1.693737e-06  49.390682
# 45          45  ENSMUSG00000026153  1.323832e-05  28.280896
#
#                     pos_iso_1                   pos_iso_2  pos_iso_1_dpi  \
# 4   ENSMUSG00000002459[4,1,2]   ENSMUSG00000002459[1,1,1]      15.593221
# 18  ENSMUSG00000048960[1,2,2]   ENSMUSG00000048960[1,9,9]      13.248768
# 38  ENSMUSG00000025933[1,1,1]   ENSMUSG00000025933[1,2,1]      19.192123
# 39  ENSMUSG00000025934[3,5,5]                         NaN      49.390682
# 45  ENSMUSG00000026153[1,8,6]  ENSMUSG00000026153[1,11,1]      16.420841
#
#     pos_iso_2_dpi                  neg_iso_1                  neg_iso_2  \
# 4        1.273254  ENSMUSG00000002459[4,1,1]  ENSMUSG00000002459[5,1,1]
# 18       7.751938  ENSMUSG00000048960[1,2,8]  ENSMUSG00000048960[1,1,1]
# 38       8.201999  ENSMUSG00000025933[2,1,1]  ENSMUSG00000025933[2,2,1]
# 39            NaN  ENSMUSG00000025934[4,5,5]  ENSMUSG00000025934[1,2,2]
# 45       6.524036  ENSMUSG00000026153[1,8,8]  ENSMUSG00000026153[1,8,7]
#
#     neg_iso_1_dpi  neg_iso_2_dpi     adj_p_val    gname feat
# 4      -13.592396      -2.439024  6.323111e-07    Rgs20  iso
# 18     -14.334039      -5.968994  3.858998e-03    Prex2  iso
# 38     -19.005775      -6.018997  1.755898e-40  Tmem14a  iso
# 39     -41.935482      -7.455196  1.939664e-05    Gsta3  iso
# 45     -15.539895     -12.741002  1.248097e-04  Fam135a  iso

# %%
gnames = ['Clu', 'Csf1', 'Irf1', 'Lamp2', 'Lsp1', 'Csf2ra']
df.loc[df.gname.isin(gnames)]
# Out:
#        Unnamed: 0                 gid         p_val        dpi  \
# 2109         2109  ENSMUSG00000014599  1.690922e-04  28.125000
# 5303         5303  ENSMUSG00000018819  2.643357e-13  51.355551
# 7491         7491  ENSMUSG00000018899  4.423150e-08  25.601851
# 11752       11752  ENSMUSG00000059326  2.536802e-38  57.361913
#
#                         pos_iso_1                   pos_iso_2  pos_iso_1_dpi  \
# 2109    ENSMUSG00000014599[1,4,1]   ENSMUSG00000014599[2,1,1]      23.437500
# 5303   ENSMUSG00000018819[4,15,1]  ENSMUSG00000018819[9,15,1]      23.025745
# 7491    ENSMUSG00000018899[2,2,1]  ENSMUSG00000018899[2,12,1]      20.462963
# 11752   ENSMUSG00000059326[4,9,1]  ENSMUSG00000059326[4,11,1]      18.218197
#
#        pos_iso_2_dpi                  neg_iso_1                   neg_iso_2  \
# 2109        4.687500  ENSMUSG00000014599[1,2,2]   ENSMUSG00000014599[1,1,1]
# 5303       10.303444  ENSMUSG00000018819[2,2,1]   ENSMUSG00000018819[2,4,1]
# 7491        5.138888  ENSMUSG00000018899[1,1,1]  ENSMUSG00000018899[2,13,1]
# 11752      15.154004  ENSMUSG00000059326[2,2,1]   ENSMUSG00000059326[1,1,1]
#
#        neg_iso_1_dpi  neg_iso_2_dpi     adj_p_val   gname feat
# 2109      -13.020833     -12.500000  1.217528e-03    Csf1  iso
# 5303      -39.454047     -11.901504  7.691031e-12    Lsp1  iso
# 7491      -21.527775      -4.074074  6.800803e-07    Irf1  iso
# 11752     -56.778931      -0.582982  2.636973e-36  Csf2ra  iso
