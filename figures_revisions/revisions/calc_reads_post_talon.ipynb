# %%
import pandas as pd
import numpy as np
import scipy.stats as st
import seaborn as sns
import sys
import os
import gseapy as gp
import matplotlib.pyplot as plt
import swan_vis as swan
import yaml
from snakemake.io import expand

p = os.path.dirname(os.path.dirname(os.getcwd()))
sys.path.append(p)

from proc_revisions.utils import *
from proc_revisions.plotting import *

# %%
od = '../../proc_revisions/'
config_file = f'{od}/config.yml'
with open(config_file) as f:
    config = yaml.safe_load(f)

# %%
ab = od+expand(config['lr']['talon']['fusion_fix']['ab'], species='human')[0]
unfilt_ab = od+expand(config['lr']['cerberus']['ab'], species='human')[0] 
filt_ab = od+expand(config['lr']['cerberus']['filt_ab'], species='human')[0]
read_annot = od+expand(config['lr']['talon']['full_annot'], species='human')[0]
t_metadata = od+expand(config['ref']['cerberus']['new_gtf_t_info'], species='human')[0]
lib_meta = od+expand(config['lr']['meta'], species='human')[0]
swan_file = od+expand(config['lr']['swan']['sg'], species='human')[0]
cerberus_h5 = od+expand(config['lr']['cerberus']['ca_triplets'], species='human', obs_col='sample')[0]
cerb_t_metadata = od+expand(config['lr']['cerberus']['gtf_t_info'], species='human')[0]
major_isos = od+expand(config['lr']['analysis']['major_isos'], species='human', obs_col='sample')[0]
pi_tpm_table = od+expand(config['lr']['mane']['pi_tpm']['triplet'], species='human', obs_col='sample')[0]

ref_t_metadata = od+expand(config['ref']['new_gtf_t_info'], species='human')[0]
ref_g_metadata = od+expand(config['ref']['new_gtf_g_info'], species='human')[0]

ver = 'v40_cerberus'
min_tpm = 1
gene_subset = 'polya'
obs_col = 'sample'
go_gene_subset = 'protein_coding'
predom_iso_subset = 'protein_coding'

m_lib_meta = od+expand(config['lr']['meta'], species='mouse')[0]
m_cerberus_h5 = od+expand(config['lr']['cerberus']['ca_triplets'], species='mouse', obs_col='sample')[0]
m_swan_file = od+expand(config['lr']['swan']['sg'], species='mouse')[0]
m_filt_ab = od+expand(config['lr']['cerberus']['filt_ab'], species='mouse')[0]
m_read_annot = od+expand(config['lr']['talon']['full_annot'], species='mouse')[0]

# %% [markdown]
# ## Recalculate the # post-talon reads for each library and add to the metadata

# %%
# human
df = pd.read_csv(read_annot, sep='\t', usecols=[0,1])
df = df.groupby('dataset').count().reset_index().rename({'read_name':'reads_post_talon'}, axis=1)
meta = pd.read_csv(lib_meta, sep='\t')
meta.drop('reads_post_talon', axis=1, inplace=True)
meta = meta.merge(df, how='left', on='dataset')
meta.to_csv(lib_meta, index=False, sep='\t')

# %%
# mouse
df = pd.read_csv(m_read_annot, sep='\t', usecols=[0,1])
df = df.groupby('dataset').count().reset_index().rename({'read_name':'reads_post_talon'}, axis=1)
meta = pd.read_csv(m_lib_meta, sep='\t')
meta.drop('reads_post_talon', axis=1, inplace=True)
meta = meta.merge(df, how='left', on='dataset')
meta.to_csv(m_lib_meta, index=False, sep='\t')

# %%
meta.head()
# Out:
#   ENCODE_experiment_id          dataset       sample       sample_display  \
# 0          ENCSR665XLM  adrenal_10d_f_1  adrenal_10d  Adrenal gland PND10
# 1          ENCSR665XLM  adrenal_10d_f_2  adrenal_10d  Adrenal gland PND10
# 2          ENCSR698DOB  adrenal_10d_m_2  adrenal_10d  Adrenal gland PND10
# 3          ENCSR698DOB  adrenal_10d_m_1  adrenal_10d  Adrenal gland PND10
# 4          ENCSR530ZLE  adrenal_14d_f_2  adrenal_14d  Adrenal gland PND14
#
#   general_tissue_cell_type fig1_tissue_label  age sex genotype  \
# 0            adrenal gland     adrenal gland  10d   f  b6/cast
# 1            adrenal gland     adrenal gland  10d   f  b6/cast
# 2            adrenal gland     adrenal gland  10d   m  b6/cast
# 3            adrenal gland     adrenal gland  10d   m  b6/cast
# 4            adrenal gland     adrenal gland  14d   f  b6/cast
#
#   tissue_or_cell_line  ... matching_human_samples ENCODE_alignments_id  \
# 0              tissue  ...      ['adrenal_gland']          ENCFF550NPJ
# 1              tissue  ...      ['adrenal_gland']          ENCFF218PAQ
# 2              tissue  ...      ['adrenal_gland']          ENCFF261QFC
# 3              tissue  ...      ['adrenal_gland']          ENCFF336YOF
# 4              tissue  ...      ['adrenal_gland']          ENCFF402PHJ
#
#   ENCODE_reads_id ENCODE_unfiltered_alignments_id  \
# 0     ENCFF321AJK                     ENCFF756SOZ
# 1     ENCFF863AGD                     ENCFF276HLF
# 2     ENCFF856RHM                     ENCFF674HLT
# 3     ENCFF303OLU                     ENCFF676ASW
# 4     ENCFF435KPO                     ENCFF704NBV
#
#                                        document_urls  \
# 0  https://www.encodeproject.org/documents/3baa46...
# 1  https://www.encodeproject.org/documents/3baa46...
# 2  https://www.encodeproject.org/documents/3baa46...
# 3  https://www.encodeproject.org/documents/3baa46...
# 4  https://www.encodeproject.org/documents/3baa46...
#
#                                      document_labels  \
# 0  'PacBio libraries v3 (October, 2020) Protocol ...
# 1  'PacBio libraries v3 (October, 2020) Protocol ...
# 2  'PacBio libraries v3 (October, 2020) Protocol ...
# 3  'PacBio libraries v3 (October, 2020) Protocol ...
# 4  'PacBio libraries v3 (October, 2020) Protocol ...
#
#                         platform  RIN  spikeins  reads_post_talon
# 0  Pacific Biosciences Sequel II  8.4      True            606677
# 1  Pacific Biosciences Sequel II  8.4      True            788654
# 2  Pacific Biosciences Sequel II  8.9      True           1407511
# 3  Pacific Biosciences Sequel II  8.9      True            971827
# 4  Pacific Biosciences Sequel II  8.5      True            991731
#
# [5 rows x 21 columns]
