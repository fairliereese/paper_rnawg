# %%
import pandas as pd
import numpy as np
import scipy.stats as st
import seaborn as sns
import sys
import os
import gseapy as gp
import matplotlib.pyplot as plt
import swan_vis as swan
import yaml
from snakemake.io import expand

# p = os.path.dirname(os.path.dirname(os.getcwd()))
# sys.path.append(p)

from scripts.utils import *
from scripts.plotting import *

# %%
config_file = 'figures/snakemake/config.yml'
with open(config_file) as f:
    config = yaml.safe_load(f)

# %%
ab = '../'+expand(config['data']['ab'], species='human')[0]
filt_ab = '../'+expand(config['data']['filt_ab'], species='human')[0]
read_annot = '../'+expand(config['data']['read_annot'], species='human')[0]
t_metadata = '../'+expand(config['ref']['cerberus']['t_info'], species='human')[0]
lib_meta = 'figures/'+expand(config['data']['meta'], species='human')[0]
swan_file = '../'+expand(config['data']['sg'], species='human')[0]
cerberus_h5 = '../'+expand(config['data']['cerb_annot'], species='human')[0]
cerb_t_metadata = '../'+expand(config['data']['t_info'], species='human')[0]
major_isos = '../'+expand(config['data']['major_isos'], species='human', obs_col='sample')[0]
pp_summary = '../'+expand(config['data']['p_pred']['summary'], species='human')[0]
ref_t_metadata = '../'+expand(config['ref']['t_info'], species='human')[0]
ref_g_metadata = '../'+expand(config['ref']['g_info'], species='human')[0]


ver = 'v40_cerberus'
min_tpm = 1
gene_subset = 'protein_coding'
obs_col = 'sample'
go_gene_subset = 'protein_coding'

m_lib_meta = 'figures/'+expand(config['data']['meta'], species='mouse')[0]

# %%
## merge lr library metadata with info diane pulled from the portal

# %%
df = pd.read_csv(lib_meta, sep='\t')
temp = pd.read_csv('figures/ref/human/human_info.tsv', sep='\t')
keep_cols = ['experiment', 'document_urls', 'document_labels', 'platform', 'RIN', 'spikeins']
temp = temp[keep_cols]
temp.drop_duplicates(inplace=True)

print(len(df.index))
df = df.merge(temp,
              how='left',
              left_on='ENCODE_experiment_id',
              right_on='experiment')
df.drop('experiment', axis=1, inplace=True)
print(len(df.index))

df['spikeins'] = ~df.spikeins.isnull()
df.to_csv(lib_meta, sep='\t', index=False)
# Out:
# 138
# 138

# %%
df.head()
# Out:
#   ENCODE_experiment_id            dataset         sample sample_display  \
# 0          ENCSR989ZYL           a673_1_1           a673           A673
# 1          ENCSR989ZYL           a673_1_2           a673           A673
# 2          ENCSR081NRO  adrenal_gland_1_1  adrenal gland  Adrenal gland
# 3          ENCSR563RLX  adrenal_gland_2_1  adrenal gland  Adrenal gland
# 4          ENCSR995WKW  adrenal_gland_3_1  adrenal gland  Adrenal gland
#
#   general_tissue_cell_type fig1_tissue_label health_status  \
# 0                     a673              bone           NaN
# 1                     a673              bone           NaN
# 2            adrenal gland     adrenal gland           NaN
# 3            adrenal gland     adrenal gland           NaN
# 4            adrenal gland     adrenal gland           NaN
#
#   tissue_or_cell_line sample_color_hex_code  \
# 0           cell_line               #de3700
# 1           cell_line               #de3700
# 2              tissue               #e69b00
# 3              tissue               #e69b00
# 4              tissue               #e69b00
#
#                               matching_mouse_samples  reads_post_talon  \
# 0                                                NaN           1330194
# 1                                                NaN           1707207
# 2  adrenal,adrenal_10d,adrenal_14d,adrenal_18-20m...            765655
# 3  adrenal,adrenal_10d,adrenal_14d,adrenal_18-20m...           1579294
# 4  adrenal,adrenal_10d,adrenal_14d,adrenal_18-20m...            577077
#
#   ENCODE_alignments_id ENCODE_reads_id ENCODE_unfiltered_alignments_id  \
# 0          ENCFF045ZQI     ENCFF168MIB                     ENCFF440LXJ
# 1          ENCFF320GCF     ENCFF861BKY                     ENCFF240FZT
# 2          ENCFF147OYL     ENCFF211SQY                     ENCFF967OHL
# 3          ENCFF791WUV     ENCFF417ALN                     ENCFF900XHI
# 4          ENCFF243PFI     ENCFF912HPY                     ENCFF020MWV
#
#                                        document_urls  \
# 0  https://www.encodeproject.org/documents/6d583a...
# 1  https://www.encodeproject.org/documents/6d583a...
# 2  https://www.encodeproject.org/documents/54012f...
# 3  https://www.encodeproject.org/documents/3baa46...
# 4  https://www.encodeproject.org/documents/54012f...
#
#                                      document_labels  \
# 0  'ENCODE Long Read RNA-Seq Analysis Protocol fo...
# 1  'ENCODE Long Read RNA-Seq Analysis Protocol fo...
# 2  'non-size selected cDNA libraries for use in P...
# 3  'PacBio libraries v3 (October, 2020) Protocol ...
# 4  'non-size selected cDNA libraries for use in P...
#
#                         platform  RIN  spikeins
# 0  Pacific Biosciences Sequel II  9.8      True
# 1  Pacific Biosciences Sequel II  9.8      True
# 2     Pacific Biosciences Sequel  9.8     False
# 3  Pacific Biosciences Sequel II  NaN      True
# 4     Pacific Biosciences Sequel  9.4     False

# %%
df = pd.read_csv(m_lib_meta, sep='\t')
temp = pd.read_csv('figures/ref/mouse/mouse_info.tsv', sep='\t')
keep_cols = ['experiment', 'document_urls', 'document_labels', 'platform', 'RIN', 'spikeins']
temp = temp[keep_cols]
temp.drop_duplicates(inplace=True)

print(len(df.index))
df = df.merge(temp,
              how='left',
              left_on='ENCODE_experiment_id',
              right_on='experiment')
df.drop('experiment', axis=1, inplace=True)
print(len(df.index))

df['spikeins'] = ~df.spikeins.isnull()
df.to_csv(m_lib_meta, sep='\t', index=False)
# Out:
# 126
# 126

# %%
df.head()
# Out:
#   ENCODE_experiment_id              dataset           sample  \
# 0          ENCSR885NRP  adrenal_18-20mo_m_1  adrenal_18-20mo
# 1          ENCSR964OKW       gastroc_4d_m_1       gastroc_4d
# 2          ENCSR964OKW       gastroc_4d_m_2       gastroc_4d
# 3          ENCSR410XGE    heart_18-20mo_m_1    heart_18-20mo
# 4          ENCSR410XGE    heart_18-20mo_m_2    heart_18-20mo
#
#            sample_display general_tissue_cell_type fig1_tissue_label      age  \
# 0  Adrenal gland PNM18-20            adrenal gland     adrenal gland  18-20mo
# 1      Gastrocnemius PND4                   muscle            muscle       4d
# 2      Gastrocnemius PND4                   muscle            muscle       4d
# 3          Heart PNM18-20                    heart             heart  18-20mo
# 4          Heart PNM18-20                    heart             heart  18-20mo
#
#   adult sex genotype  ... matching_human_samples reads_post_talon  \
# 0  True   m  b6/cast  ...      ['adrenal gland']           679622
# 1  True   m  b6/cast  ...             ['muscle']          1066347
# 2  True   m  b6/cast  ...             ['muscle']          1100253
# 3  True   m  b6/cast  ...              ['heart']           699529
# 4  True   m  b6/cast  ...              ['heart']          1019974
#
#   ENCODE_alignments_id  ENCODE_reads_id ENCODE_unfiltered_alignments_id  \
# 0          ENCFF684SLZ      ENCFF811RRD                     ENCFF167IJD
# 1          ENCFF643TDK      ENCFF798HCT                     ENCFF541JWV
# 2          ENCFF821NRP      ENCFF069POP                     ENCFF362LGG
# 3          ENCFF800GKP      ENCFF177KNR                     ENCFF458JBD
# 4          ENCFF510KLD      ENCFF468BPP                     ENCFF107ZLE
#
#                                        document_urls  \
# 0  https://www.encodeproject.org/documents/3baa46...
# 1  https://www.encodeproject.org/documents/3baa46...
# 2  https://www.encodeproject.org/documents/3baa46...
# 3  https://www.encodeproject.org/documents/bf543f...
# 4  https://www.encodeproject.org/documents/bf543f...
#
#                                      document_labels  \
# 0  'PacBio libraries v3 (October, 2020) Protocol ...
# 1  'PacBio libraries v3 (October, 2020) Protocol ...
# 2  'PacBio libraries v3 (October, 2020) Protocol ...
# 3  'ENCODE Long Read RNA-Seq Analysis Protocol fo...
# 4  'ENCODE Long Read RNA-Seq Analysis Protocol fo...
#
#                         platform  RIN spikeins
# 0  Pacific Biosciences Sequel II  8.1     True
# 1  Pacific Biosciences Sequel II  9.0     True
# 2  Pacific Biosciences Sequel II  9.0     True
# 3  Pacific Biosciences Sequel II  8.0     True
# 4  Pacific Biosciences Sequel II  8.0     True
#
# [5 rows x 22 columns]

# %%
df = pd.read_csv(m_lib_meta, sep='\t')
# df.drop(['document_urls', 'document_labels', 'platform', 'RIN', 'spikeins'], axis=1, inplace=True)
# df.to_csv(m_lib_meta, sep='\t', index=False)
df.columns
# Out:
# Index(['ENCODE_experiment_id', 'dataset', 'sample', 'sample_display',
#        'general_tissue_cell_type', 'fig1_tissue_label', 'age', 'adult', 'sex',
#        'genotype', 'tissue_or_cell_line', 'sample_color_hex_code',
#        'matching_human_samples', 'reads_post_talon', 'ENCODE_alignments_id',
#        'ENCODE_reads_id', 'ENCODE_unfiltered_alignments_id'],
#       dtype='object')

# %%
## procap stuff

# %%
# procap meta
procap_meta = pd.read_csv('figures/'+expand(config['procap']['lib_meta'],
                                 species='human')[0],
                                 sep='\t')

expand(expand(config['procap']['bed'],
       zip,
       dataset=procap_meta.dataset.unique().tolist(),
       allow_missing=True),
       species='human',
       output_type=['bidirectional peaks', 'unidirectional peaks'])
# Out:
# []

# %%
expand(config['procap']['bed'],
       zip,
       procap_dataset=procap_meta.dataset.unique().tolist(),
       allow_missing=True)
# Out:
# ['data/{species}/procap/mcf10a_1_{output_type}.bed',
#  'data/{species}/procap/k562_5_{output_type}.bed',
#  'data/{species}/procap/k562_6_{output_type}.bed',
#  'data/{species}/procap/k562_2_{output_type}.bed',
#  'data/{species}/procap/k562_4_{output_type}.bed',
#  'data/{species}/procap/k562_1_{output_type}.bed',
#  'data/{species}/procap/caco2_1_{output_type}.bed',
#  'data/{species}/procap/huvec_1_{output_type}.bed',
#  'data/{species}/procap/calu3_1_{output_type}.bed',
#  'data/{species}/procap/k562_3_{output_type}.bed',
#  'data/{species}/procap/a673_1_{output_type}.bed']

# %%
procap_meta.dataset.unique().tolist()
# Out:
# ['mcf10a_1',
#  'k562_5',
#  'k562_6',
#  'k562_2',
#  'k562_4',
#  'k562_1',
#  'caco2_1',
#  'huvec_1',
#  'calu3_1',
#  'k562_3',
#  'a673_1']

# %%
species=['human', 'mouse']
def get_meta_df():
    meta_df = pd.DataFrame()
    for f, s in zip(list(expand(config['data']['meta'], species=species)), species):
        temp = pd.read_csv('figures/'+f, sep='\t')
        temp['species'] = s
        meta_df = pd.concat([meta_df, temp], axis=0)
    # if meta_df.dataset.duplicated.any():
    #     raise ValueError('Mouse and human dataset names not unique')
    return meta_df
meta_df = get_meta_df()

# %%
len(meta_df)
# Out:
# 264

# %%
df = pd.read_csv('figures/ref/lr_file_ids.tsv', sep='\t')

# %%
df = df[['name', 'file', 'output_type']].pivot(values='file',
                                                     index='name',
                                       columns='output_type')

# %%
df.head()
# Out:
# output_type       alignments        reads unfiltered alignments
# name
# ENCSR026WRM_1_1  ENCFF753VCG  ENCFF402OZL           ENCFF655BWX
# ENCSR026WRM_2_1  ENCFF587QKV  ENCFF182ZKL           ENCFF574LQO
# ENCSR044ARQ_1_1  ENCFF292UIE  ENCFF688QGB           ENCFF193ZRQ
# ENCSR044ARQ_2_1  ENCFF738RAA  ENCFF272VSN           ENCFF455IAW
# ENCSR056MYH_1_1  ENCFF319JFG  ENCFF026VEI           ENCFF858LGV

# %%
meta_df = pd.read_csv(lib_meta, sep='\t')
meta_df.head()
meta_df = meta_df.merge(df, how='left', left_on='ENCODE_file_id', right_on='alignments')

# %%
meta_df.drop(['ENCODE_file_id'], axis=1, inplace=True)
meta_df.rename({'alignments': 'ENCODE_alignments_id',
                'unfiltered alignments': 'ENCODE_unfiltered_alignments_id',
                'reads': 'ENCODE_reads_id'}, axis=1, inplace=True)

# %%
meta_df.to_csv(lib_meta, sep='\t', index=False)

# %%
meta_df = pd.read_csv(m_lib_meta, sep='\t')
meta_df.head()
meta_df = meta_df.merge(df, how='left', left_on='ENCODE_file_id', right_on='alignments')
meta_df.drop(['ENCODE_file_id'], axis=1, inplace=True)
meta_df.rename({'alignments': 'ENCODE_alignments_id',
                'unfiltered alignments': 'ENCODE_unfiltered_alignments_id',
                'reads': 'ENCODE_reads_id'}, axis=1, inplace=True)
meta_df.to_csv(m_lib_meta, sep='\t', index=False)

# %%
meta_df.head()
# Out:
#   ENCODE_experiment_id              dataset           sample  \
# 0          ENCSR885NRP  adrenal_18-20mo_m_1  adrenal_18-20mo
# 1          ENCSR964OKW       gastroc_4d_m_1       gastroc_4d
# 2          ENCSR964OKW       gastroc_4d_m_2       gastroc_4d
# 3          ENCSR410XGE    heart_18-20mo_m_1    heart_18-20mo
# 4          ENCSR410XGE    heart_18-20mo_m_2    heart_18-20mo
#
#            sample_display general_tissue_cell_type fig1_tissue_label      age  \
# 0  Adrenal gland PNM18-20            adrenal gland     adrenal gland  18-20mo
# 1      Gastrocnemius PND4                   muscle            muscle       4d
# 2      Gastrocnemius PND4                   muscle            muscle       4d
# 3          Heart PNM18-20                    heart             heart  18-20mo
# 4          Heart PNM18-20                    heart             heart  18-20mo
#
#   adult sex genotype tissue_or_cell_line sample_color_hex_code  \
# 0  True   m  b6/cast              tissue               #b24422
# 1  True   m  b6/cast              tissue               #e2e5ef
# 2  True   m  b6/cast              tissue               #e2e5ef
# 3  True   m  b6/cast              tissue               #7caf5c
# 4  True   m  b6/cast              tissue               #7caf5c
#
#   matching_human_samples  reads_post_talon ENCODE_alignments_id  \
# 0      ['adrenal gland']            679622          ENCFF684SLZ
# 1             ['muscle']           1066347          ENCFF643TDK
# 2             ['muscle']           1100253          ENCFF821NRP
# 3              ['heart']            699529          ENCFF800GKP
# 4              ['heart']           1019974          ENCFF510KLD
#
#   ENCODE_reads_id ENCODE_unfiltered_alignments_id
# 0     ENCFF811RRD                     ENCFF167IJD
# 1     ENCFF798HCT                     ENCFF541JWV
# 2     ENCFF069POP                     ENCFF362LGG
# 3     ENCFF177KNR                     ENCFF458JBD
# 4     ENCFF468BPP                     ENCFF107ZLE

# %%
## make sure thing is working for getting correct type of file

# %%
def get_df_lr_ids(file_id_df, file_format, species):
    df = file_id_df.copy(deep=True)
    if file_format == 'bam':
        df = df.loc[df.output_type=='unfiltered alignments']
    elif file_format == 'label_bam':
        df = df.loc[df.output_type=='alignments']
    elif file_format == 'fastq':
        df = df.loc[df.output_type=='reads']
    df = df.loc[df.species==species]
    ids = df.file.tolist()
    return ids

# %%
file_id_df = pd.read_csv('figures/ref/lr_file_ids.tsv', sep='\t')

# %%
file_id_df[['file', 'output_type', 'species']].groupby(['output_type', 'species']).count()
# Out:
#                                file
# output_type           species
# alignments            human     138
#                       mouse     126
# reads                 human     138
#                       mouse     126
# unfiltered alignments human     138
#                       mouse     126

# %%
# 230722 test get_lr_ids

# %%
def get_lr_ids(file_format='bam', species='human'):
    metadata = get_lr_exp_meta(species)
    if file_format == 'bam':
        metadata = metadata.loc[metadata.output_type=='unfiltered alignments']
    elif file_format == 'label_bam':
        metadata = metadata.loc[metadata.output_type=='alignments']
    elif file_format == 'fastq':
        metadata = metadata.loc[metadata.output_type=='reads']

    return metadata.file.tolist()

# %%
get_lr_ids('label_bam', 'human')
# Out:
# ['ENCFF158KCA',
#  'ENCFF147OYL',
#  'ENCFF772MSZ',
#  'ENCFF117DUA',
#  'ENCFF648NAR',
#  'ENCFF225CCJ',
#  'ENCFF016SHE',
#  'ENCFF479EHE',
#  'ENCFF914XOH',
#  'ENCFF745DHX',
#  'ENCFF846YHI',
#  'ENCFF049QGQ',
#  'ENCFF243PFI',
#  'ENCFF936VUF',
#  'ENCFF939EUU',
#  'ENCFF545PJV',
#  'ENCFF504GVG',
#  'ENCFF479SQR',
#  'ENCFF400LRT',
#  'ENCFF989FKA',
#  'ENCFF596ODX',
#  'ENCFF192PJS',
#  'ENCFF694CBG',
#  'ENCFF538BNH',
#  'ENCFF814ABW',
#  'ENCFF168AZV',
#  'ENCFF362CPC',
#  'ENCFF940WVU',
#  'ENCFF973OML',
#  'ENCFF058HQU',
#  'ENCFF292UIE',
#  'ENCFF738RAA',
#  'ENCFF925MYC',
#  'ENCFF558QPF',
#  'ENCFF118JEI',
#  'ENCFF322UJU',
#  'ENCFF044LIA',
#  'ENCFF219UJG',
#  'ENCFF509GHY',
#  'ENCFF803KIA',
#  'ENCFF213XDA',
#  'ENCFF281VKZ',
#  'ENCFF250BDM',
#  'ENCFF810FRP',
#  'ENCFF600MGT',
#  'ENCFF661OEY',
#  'ENCFF645UVN',
#  'ENCFF100RGC',
#  'ENCFF927MKK',
#  'ENCFF470UHX',
#  'ENCFF054YYA',
#  'ENCFF319JFG',
#  'ENCFF901XCR',
#  'ENCFF319FBW',
#  'ENCFF992ZVE',
#  'ENCFF373TKM',
#  'ENCFF985LGZ',
#  'ENCFF388HXU',
#  'ENCFF291EKY',
#  'ENCFF791WUV',
#  'ENCFF193WEX',
#  'ENCFF626QRV',
#  'ENCFF239CWJ',
#  'ENCFF779VVX',
#  'ENCFF099TJN',
#  'ENCFF439BVT',
#  'ENCFF545CXA',
#  'ENCFF469ATL',
#  'ENCFF623IBV',
#  'ENCFF850YMO',
#  'ENCFF767KXS',
#  'ENCFF731THW',
#  'ENCFF132YCF',
#  'ENCFF745HHL',
#  'ENCFF660UTF',
#  'ENCFF171AQO',
#  'ENCFF018PZX',
#  'ENCFF757LOZ',
#  'ENCFF886FZQ',
#  'ENCFF074WRN',
#  'ENCFF344KQF',
#  'ENCFF449MVA',
#  'ENCFF911RNV',
#  'ENCFF613SDS',
#  'ENCFF437SYY',
#  'ENCFF583MSU',
#  'ENCFF840OVC',
#  'ENCFF472TSL',
#  'ENCFF984RMR',
#  'ENCFF809QBD',
#  'ENCFF875QHC',
#  'ENCFF693YCD',
#  'ENCFF971JDY',
#  'ENCFF698UNA',
#  'ENCFF924HBV',
#  'ENCFF502LAB',
#  'ENCFF173JOL',
#  'ENCFF644PGG',
#  'ENCFF305AFY',
#  'ENCFF903XBV',
#  'ENCFF349CHO',
#  'ENCFF600UQU',
#  'ENCFF049QIP',
#  'ENCFF563QXX',
#  'ENCFF395SXY',
#  'ENCFF045ZQI',
#  'ENCFF320GCF',
#  'ENCFF893MWY',
#  'ENCFF832PKO',
#  'ENCFF531AEO',
#  'ENCFF074AZE',
#  'ENCFF551HOX',
#  'ENCFF856OAO',
#  'ENCFF835KGV',
#  'ENCFF899RYN',
#  'ENCFF215GZH',
#  'ENCFF945VII',
#  'ENCFF990ZNY',
#  'ENCFF702KGD',
#  'ENCFF007EDQ',
#  'ENCFF259PEY',
#  'ENCFF100YYU',
#  'ENCFF100EPL',
#  'ENCFF624BUU',
#  'ENCFF172UBZ',
#  'ENCFF294TRC',
#  'ENCFF535QSI',
#  'ENCFF950CCD',
#  'ENCFF103QSB',
#  'ENCFF406GQU',
#  'ENCFF279ABL',
#  'ENCFF114VSO',
#  'ENCFF773RAW',
#  'ENCFF222UTL',
#  'ENCFF564ONS',
#  'ENCFF678TEN',
#  'ENCFF877QJZ',
#  'ENCFF378STM']
